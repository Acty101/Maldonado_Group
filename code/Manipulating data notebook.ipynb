# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/Kit/Documents/PyCharm/venv/data/third_loop_output.09-23-2022.20-07-23.csv")

# %%
df.head()
# Out:
#    E_app_corr  J_model_calculation1
# 0    1.044723          2.223713e-35
# 1    1.034723          1.700453e-35
# 2    1.024723          2.606874e-35
# 3    1.014723          3.680737e-35
# 4    1.004723          5.383522e-35

# %%
df.plot(x ='E_app_corr', y='J_model_calculation1', kind = 'line')
# Out:
# <AxesSubplot:xlabel='E_app_corr'>

# %%
s_array = df[["E_app_corr", "J_model_calculation1"]].to_numpy()

# %%
print(s_array[:,1])
# Out:
# [ 2.22371332e-35  1.70045259e-35  2.60687413e-35  3.68073664e-35
#   5.38352224e-35  7.89648056e-35  1.16230138e-34  1.71315600e-34
#   2.52703899e-34  3.72910260e-34  5.50422218e-34  8.12538134e-34
#   1.19956560e-33  1.77101921e-33  2.61477196e-33  3.86056732e-33
#   5.69996953e-33  8.41581995e-33  1.24257289e-32  1.83462904e-32
#   2.70878944e-32  3.99947152e-32  5.90514012e-32  8.71882499e-32
#   1.28731792e-31  1.90070072e-31  2.80634919e-31  4.14352262e-31
#   6.11783480e-31  9.03287079e-31  1.33368685e-30  1.96916430e-30
#   2.90743525e-30  4.29277538e-30  6.33820513e-30  9.35824538e-30
#   1.38172807e-29  2.04009665e-29  3.01216610e-29  4.44740934e-29
#   6.56652047e-29  9.69535050e-29  1.43150127e-28  2.11358624e-28
#   3.12067270e-28  4.60761818e-28  6.80306713e-28  1.00446091e-27
#   1.48306894e-27  2.18972538e-27  3.23309135e-27  4.77360316e-27
#   7.04814227e-27  1.04064601e-26  1.53649588e-26  2.26860972e-26
# ...

# %%
plt.plot(s_array[:,0],s_array[:,1])

# %%
num_array = np.genfromtxt('C:/Users/Kit/Documents/PyCharm/venv/data/third_loop_output.09-23-2022.20-07-23.csv', delimiter=',')

# %%
# Out:
# [[            nan             nan]
#  [ 1.04472263e+00  2.22371332e-35]
#  [ 1.03472263e+00  1.70045259e-35]
#  ...
#  [ 1.02472263e+00 -6.37211437e-08]
#  [ 1.03472263e+00 -6.33067556e-08]
#  [ 1.04472263e+00 -6.28969812e-08]]
